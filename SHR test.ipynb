# %%
import pandas as pd

# %%
shr_df = pd.read_excel("shr/shr_2015/shr_2015.xlsx")

# %%
shr_df
# Out:
#     V2       V3  V4  V5    V6      V7  V8   V9  V10         V11 ...  V143  \
# V1                                                              ...
# 6    1  AL00112   3   6  2012   82332  37   98    0      HOOVER ...
# 6    1  AL00112   3   6  2012   82332  37   98    0      HOOVER ...
# 6    2  AZ00101   6   8  2012    5008   1         0       EAGAR ...
# 6    2  AZ00200  9B   8  2012   52333   2  816    1     COCHISE ...
# 6    2  AZ00200  9B   8  2012   52333   2  816    1     COCHISE ...
# 6    2  AZ00203   6   8  2012    5694   2  816    1      BISBEE ...
# 6    2  AZ00205   5   8  2012   17743   2  816    0     DOUGLAS ...
# 6    2  AZ00300  9B   8  2012   54753   3  275    1    COCONINO ...
# 6    2  AZ00300  9B   8  2012   54753   3  275    1    COCONINO ...
# 6    2  AZ00308   6   8  2012    7331   3  275    1        PAGE ...
# 6    2  AZ00308   6   8  2012    7331   3  275    1        PAGE ...
# 6    2  AZ00406   5   8  2012   15337   4         0      PAYSON ...
# ...

# %%
shr_useful = shr_df[['V2', 'V8', 'V11']]
print(shr_useful.shape)
shr_useful.head()
# Out:
# (13063, 3)
#     V2  V8      V11
# V1
# 6    1  37   HOOVER
# 6    1  37   HOOVER
# 6    2   1    EAGAR
# 6    2   2  COCHISE
# 6    2   2  COCHISE

# %%
locations = {"MARICOPA", "ST. CROIX", "ST. THOMAS", "HOOVER"}

a = 'V11'
b = 'V2'
c = 'V8'
b_val = 2
c_val = '11'

shr_useful.loc[(shr_useful['V11'].isin(locations)) & (shr_useful['V2'] == 2) & (shr_useful['V8'] == '11')]
# Out:
#     V2  V8       V11
# V1
# 6    2  11  MARICOPA

# %%
replace_V8 = { '37' : 'a', '1' : 'b'}
replace_V2 = { 1 : 'wow' }
shr_useful.replace(to_replace={'V8' : replace_V8, 'V2' : replace_V2})
# Out:
#      V2 V8         V11
# V1
# 6   wow  a      HOOVER
# 6   wow  a      HOOVER
# 6     2  b       EAGAR
# 6     2  2     COCHISE
# 6     2  2     COCHISE
# 6     2  2      BISBEE
# 6     2  2     DOUGLAS
# 6     2  3    COCONINO
# 6     2  3    COCONINO
# 6     2  3        PAGE
# 6     2  3        PAGE
# 6     2  4      PAYSON
# 6     2  5      GRAHAM
# 6     2  6    GREENLEE
# 6     2  7    MARICOPA
# 6     2  7    MARICOPA
# 6     2  7    MARICOPA
# 6     2  7    MARICOPA
# 6     2  7    MARICOPA
# 6     2  7    MARICOPA
# 6     2  7    MARICOPA
# 6     2  7    MARICOPA
# 6     2  7    MARICOPA
# 6     2  7    MARICOPA
# 6     2  7    AVONDALE
# 6     2  7    AVONDALE
# 6     2  7    AVONDALE
# 6     2  7    AVONDALE
# 6     2  7    AVONDALE
# 6     2  7    AVONDALE
# ..  ... ..         ...
# 6    62     ST. THOMAS
# 6    62     ST. THOMAS
# 6    62     ST. THOMAS
# 6    62     ST. THOMAS
# 6    62     ST. THOMAS
# 6    62     ST. THOMAS
# 6    62      ST. CROIX
# ...

# %%
shr_df.V19.unique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6f8f09ac7adc> in <module>()
# ----> 1 shr_df.V19.unique()
#
# NameError: name 'shr_df' is not defined

# %%
shr_useful
# Out:
#     V2 V8         V11
# V1
# 6    1  a      HOOVER
# 6    1  a      HOOVER
# 6    2  b       EAGAR
# 6    2  2     COCHISE
# 6    2  2     COCHISE
# 6    2  2      BISBEE
# 6    2  2     DOUGLAS
# 6    2  3    COCONINO
# 6    2  3    COCONINO
# 6    2  3        PAGE
# 6    2  3        PAGE
# 6    2  4      PAYSON
# 6    2  5      GRAHAM
# 6    2  6    GREENLEE
# 6    2  7    MARICOPA
# 6    2  7    MARICOPA
# 6    2  7    MARICOPA
# 6    2  7    MARICOPA
# 6    2  7    MARICOPA
# 6    2  7    MARICOPA
# 6    2  7    MARICOPA
# 6    2  7    MARICOPA
# 6    2  7    MARICOPA
# 6    2  7    MARICOPA
# 6    2  7    AVONDALE
# 6    2  7    AVONDALE
# 6    2  7    AVONDALE
# 6    2  7    AVONDALE
# 6    2  7    AVONDALE
# 6    2  7    AVONDALE
# ..  .. ..         ...
# 6   62     ST. THOMAS
# 6   62     ST. THOMAS
# 6   62     ST. THOMAS
# 6   62     ST. THOMAS
# 6   62     ST. THOMAS
# 6   62     ST. THOMAS
# 6   62      ST. CROIX
# 6   62      ST. CROIX
# 6   62      ST. CROIX
# ...

# %%
def label_unique(row):
    return row['V3'] + '-' + row['V17']

def label_death_eligible(row):
    V29 = { 3, 5, 2, 9, 46, 49, 48 }
    val = row['V19']
    #handle killings by people below 16 (EXCLUDE)
    
    if (row['V31'] > 0):
        return 1
    if (row['V29'] in V29)
        return 1
    if (val == 'BB' or val == 'NB' or (val < 6 and val != 0):
        return 1
    return 0
